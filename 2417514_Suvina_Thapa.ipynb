# %% [markdown]
# **Probem 1**
#
#
# Data Exploration and Understanding:
# • Dataset Overview:
# 1. Load the dataset and display the first 10 rows.
# 2. Identify the number of rows and columns in the dataset.
# 3. List all the columns and their data types.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/2417514_SuvinaThapa_assigment
# Out:
# /content/drive/MyDrive/2417514_SuvinaThapa_assigment

# %%
# !ls
# Out:
# '2417514_Suvina Thapa.ipynb'   SouthAsia.csv		   WHR-2024-5CS037.csv
#  MiddleEasternCountries.csv    south_asian_countries.csv

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('WHR-2024-5CS037.csv')
df.head(10)
rows, columns = df.shape
print(f"Number of rows: {rows}, Number of columns: {columns}")
#for column list and datatype
df.dtypes
# Out:
# Number of rows: 143, Number of columns: 9
# Country name                     object
# score                           float64
# Log GDP per capita              float64
# Social support                  float64
# Healthy life expectancy         float64
# Freedom to make life choices    float64
# Generosity                      float64
# Perceptions of corruption       float64
# Dystopia + residual             float64
# dtype: object

# %% [markdown]
# Basic Statistics:
# 1. Calculate the mean, median, and standard deviation for the Score column.
# 2. Identify the country with the highest and lowest happiness scores.

# %%
df = pd.read_csv('WHR-2024-5CS037.csv')
mean_score = df['score'].mean()
median_score = df['score'].median()
std_score = df['score'].std()

print(f'Mean Score: {mean_score}')
print(f'Median Score: {median_score}')
print(f'Standard Deviation of Score: {std_score}')
# Out:
# Mean Score: 5.52758041958042
# Median Score: 5.785
# Standard Deviation of Score: 1.1707165099442995

# %% [markdown]
# Missing Values:
# 1. Check if there are any missing values in the dataset. If so, display the total count for each column.

# %%
df = pd.read_csv('WHR-2024-5CS037.csv')
missing_values = df.isnull().sum()
print("Missing values count for each column:")
missing_values
# Out:
# Missing values count for each column:
# Country name                    0
# score                           0
# Log GDP per capita              3
# Social support                  3
# Healthy life expectancy         3
# Freedom to make life choices    3
# Generosity                      3
# Perceptions of corruption       3
# Dystopia + residual             3
# dtype: int64

# %% [markdown]
# Filtering and Sorting:
# 1. Filter the dataset to show only the countries with a Score greater than 7.5.
# 2. For the filtered dataset - Sort the dataset by GDP per Capita in descending order and display the
# top 10 rows.

# %%
filtered_df = df[df['score'] > 7.5]
sorted_df = filtered_df.sort_values(by='Log GDP per capita', ascending=False)
top_10_rows = sorted_df.head(10)
print("Top 10 rows with Score greater than 7.5:")
top_10_rows
# Out:
# Top 10 rows with Score greater than 7.5:
#   Country name  score  Log GDP per capita  Social support  \
# 1      Denmark  7.583               1.908           1.520
# 2      Iceland  7.525               1.881           1.617
# 0      Finland  7.741               1.844           1.572
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 1                    0.699                         0.823       0.204
# 2                    0.718                         0.819       0.258
# 0                    0.695                         0.859       0.142
#
#    Perceptions of corruption  Dystopia + residual
# 1                      0.548                1.881
# 2                      0.182                2.050
# 0                      0.546                2.082

# %% [markdown]
# New Columns:
# 1. Create a new column called Happiness Category that categorizes countries into three categories
# based on their Score:
#
# Low − (Score < 4)
# Medium − (4 ≤ Score ≤ 6)
# High − (Score > 6)

# %%
df['Happiness Cateogory'] = df['score'].apply(lambda x: 'Low' if x < 4 else ('Medium' if 4 <= x <= 6 else 'High'))
df.head()
# Out:
#   Country name  score  Log GDP per capita  Social support  \
# 0      Finland  7.741               1.844           1.572
# 1      Denmark  7.583               1.908           1.520
# 2      Iceland  7.525               1.881           1.617
# 3       Sweden  7.344               1.878           1.501
# 4       Israel  7.341               1.803           1.513
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.695                         0.859       0.142
# 1                    0.699                         0.823       0.204
# 2                    0.718                         0.819       0.258
# 3                    0.724                         0.838       0.221
# 4                    0.740                         0.641       0.153
#
#    Perceptions of corruption  Dystopia + residual Happiness Cateogory
# 0                      0.546                2.082                High
# ...

# %% [markdown]
# 2. Data Visualizations:
# • Bar Plot: Plot the top 10 happiest countries by Score using a bar chart.
# • Line Plot: Plot the top 10 unhappiest countries by Score using a Line chart.
# • Plot a histogram for the Score column to show its distribution and also interpret.
# • Scatter Plot: Plot a scatter plot between GDP per Capita and Score to visualize their relationship.

# %%
#Bar PLot
plt.figure(figsize=(10, 6))
sns.set(style="ticks")
top_10_happiest = df.sort_values(by='score', ascending=False).head(10)
sns.barplot(x='Country name', y='score', data=top_10_happiest, hue='Country name')
plt.title('Top 10 Happiest Countries by Score')
plt.xlabel('Country name')
plt.ylabel('score')
plt.xticks(rotation=0, ha ='center')
plt.tight_layout()
plt.show()

# %% [markdown]
# 2.Line Plot: Plot the top 10 unhappiest countries by Score using a Line chart.

# %%
#Line Plot
top_10_unhappiest = df.sort_values(by='score', ascending=True).head(10)
plt.figure(figsize=(10, 6))
sns.lineplot(x='Country name', y='score', data=top_10_unhappiest,marker='o', color='blue')
sns.set(style='ticks')
plt.title(  'Top 10 Unhappiest Countries by Score')
plt.xlabel('Country')
plt.ylabel('Score')
plt.xticks(rotation=45, ha='right')
plt.show()

# %% [markdown]
#  • Plot a histogram for the Score column to show its distribution and also interpret.

# %%
#Plot histogram
plt.figure(figsize=(8,6))
sns.histplot(df['score'], bins=10, kde=True, color='skyblue')
sns.set(style='ticks')
plt.title('Distribution of Score')
plt.xlabel('Score')
plt.ylabel('Frequency')
plt.tight_layout()
plt.show()

# %% [markdown]
#  • Scatter Plot: Plot a scatter plot between GDP per Capita and Score to visualize their relationship.

# %%
#Scatter Plot
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Log GDP per capita', y='score', data=df,hue='score')
sns.set(style='ticks')
plt.title('Relationship between GDP per capital and score')
plt.xlabel('GDP per Capita')
plt.ylabel('Score')
plt.show()

# %% [markdown]
# 3.2 Problem - 2 - Some Advance Data Exploration Task:
# Task - 1 - Setup Task - Preparing the South-Asia Dataset:
# Steps:
# 1. Define the countries in South Asia with a list for example:
# south asian countries = ["Afghanistan", "Bangladesh", "Bhutan", "India",
#
# "Maldives", "Nepal", "Pakistan", "Srilanka"]
#
# 2. Use the list from step - 1 to filtered the dataset {i.e. filtered out matching dataset from list.}
# 3. Save the filtered dataframe as separate CSV files for future use.

# %%
south_asian_countries = ["Afghanistan", "Bangladesh", "Bhutan", "India", "Maldives", "Nepal", "Pakistan", "Srilanka"]
south_country_df = df[df['Country name'].isin(south_asian_countries)]
#saving new csv file as south_asian_countries
south_country_df.to_csv('SouthAsia.csv', index=False)
south_country_df.head()
# Out:
#     Country name  score  Log GDP per capita  Social support  \
# 92         Nepal  5.158               0.965           0.990
# 107     Pakistan  4.657               1.069           0.600
# 125        India  4.054               1.166           0.653
# 128   Bangladesh  3.886               1.122           0.249
# 142  Afghanistan  1.721               0.628           0.000
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 92                     0.443                         0.653       0.209
# 107                    0.321                         0.542       0.144
# 125                    0.417                         0.767       0.174
# 128                    0.513                         0.775       0.140
# 142                    0.242                         0.000       0.091
#
#      Perceptions of corruption  Dystopia + residual Happiness Cateogory
# 92                       0.115                1.783              Medium
# ...

# %% [markdown]
# Task - 2 - Composite Score Ranking:
# Tasks:
# 1. Using the SouthAsia DataFrame, create a new column called Composite Score that combines the
# following metrics:
#
# Composite Score = 0.40 × GDP per Capita + 0.30 × Social Support
#
# + 0.30 × Healthy Life Expectancy

# %%
south_country_df = pd.read_csv('SouthAsia.csv')
south_country_df['Composite Score'] = (
    0.40 * (south_country_df['Log GDP per capita']) +
    0.30 * (south_country_df['Social support']) +
    0.30 * (south_country_df['Healthy life expectancy'])
)
south_country_df.head()
# Out:
#   Country name  score  Log GDP per capita  Social support  \
# 0        Nepal  5.158               0.965           0.990
# 1     Pakistan  4.657               1.069           0.600
# 2        India  4.054               1.166           0.653
# 3   Bangladesh  3.886               1.122           0.249
# 4  Afghanistan  1.721               0.628           0.000
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.443                         0.653       0.209
# 1                    0.321                         0.542       0.144
# 2                    0.417                         0.767       0.174
# 3                    0.513                         0.775       0.140
# 4                    0.242                         0.000       0.091
#
#    Perceptions of corruption  Dystopia + residual Happiness Cateogory  \
# 0                      0.115                1.783              Medium
# ...

# %% [markdown]
# 2. Rank the South Asian countries based on the Composite Score in descending order.
#
# ---

# %%
ranked_southasia_countries = south_country_df.sort_values(by='Composite Score', ascending=False)
#select specific columns
ranked_southasia_countries[['Country name', 'Composite Score']]
# Out:
#   Country name  Composite Score
# 0        Nepal           0.8159
# 2        India           0.7874
# 1     Pakistan           0.7039
# 3   Bangladesh           0.6774
# 4  Afghanistan           0.3238

# %% [markdown]
# 3. Visualize the top 5 countries using a horizontal bar chart showing the Composite Score.

# %%
top_5_countries = ranked_southasia_countries.head(5)
plt.figure(figsize=(10, 6))
sns.barplot(x='Composite Score', y='Country name', data=top_5_countries, hue='score')
plt.title('Top 5 South Asian Countries by Composite Score')
plt.xlabel('Composite Score')
plt.ylabel('Country')
# Out:
# Text(0, 0.5, 'Country')

# %% [markdown]
# 4. Discuss whether the rankings based on the Composite Score align with the original Score - support your
# discussion with some visualization plot.

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='score', y='Country name', data=top_5_countries, color='skyblue', label='Original Score')
sns.barplot(x='Composite Score', y='Country name', data=top_5_countries, color='green', label='Composite Score')
plt.title('Comparison of Original Score vs Composite Score (Top 5 Countries)')
plt.xlabel('Score')
plt.ylabel('Country')
plt.legend()
plt.show()

# %% [markdown]
# Task - 3 - Outlier Detection:
# Tasks:
# 1. Identify outlier countries in South Asia based on their Score and GDP per Capita.

# %%
Q1_asia_score = south_country_df['score'].quantile(0.25)
Q3_asia_score = south_country_df['score'].quantile(0.75)
IQR_asia_score = Q3_asia_score - Q1_asia_score

#to findquartile for gdp
Q1_asia_gdp = south_country_df['Log GDP per capita'].quantile(0.25)
Q3_asia_gdp = south_country_df['Log GDP per capita'].quantile(0.75)
IQR_asia_gdp = Q3_asia_gdp - Q1_asia_gdp

#For upper and lower bound for outlier to lie
upper_score = Q3_asia_score + 1.5 * IQR_asia_score
lower_score = Q1_asia_score - 1.5 * IQR_asia_score

upper_gdp = Q3_asia_gdp + 1.5 * IQR_asia_gdp
lower_gdp = Q1_asia_gdp - 1.5 * IQR_asia_gdp

#Identifying outlier
outlier_identify = south_country_df[
   ((south_country_df['score'] > upper_score) | (south_country_df['score'] < lower_score))  &
   ((south_country_df['Log GDP per capita'] > upper_gdp) | (south_country_df['Log GDP per capita'] < lower_gdp)
    )
]
outlier_identify[['Country name','score','Log GDP per capita']]
# Out:
#   Country name  score  Log GDP per capita
# 4  Afghanistan  1.721               0.628

# %% [markdown]
# 2. Define outliers using the 1.5 × IQR rule.
#
# -> Outlier using the 1.5 x IQR rule is defined as a data points that belong outside the range of lower bound(Q1-1.5 x IQR) to upper bound(Q3 + 1.5 x IQR) where Q1 and Q3 are 1st quartile and third quartile respecitvely and IQr is also known as Q3-Q1.

# %% [markdown]
# 3. Create a scatter plot with GDP per Capita on the x-axis and Score on the y-axis, highlighting outliers
# in a different color.

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x='Log GDP per capita', y='score', data=south_country_df, hue='Country name')
plt.title('Scatter Plot of Score vs. GDP per Capita')
plt.xlabel('GDP per Capita')
plt.ylabel('Score')
plt.legend(title='Outlier', labels=['No', 'Yes'])
plt.show()

# %% [markdown]
# 4. Discuss the characteristics of these outliers and their potential impact on regional averages.
#
# -> The characteristics of outlier are:
#
# 1. Atypical Sores or GDP : It display significantly different scores or GDP per capita comapred to their south asian coutries with having high or low values for measurement.
#
# 2.Combined derivations : It exhibits a unusal combination between score and gdp where score and economic perfomance doesn't align with regional trends.
#
#
#
# -> Potential Impacts:
#
# 1. It explain how outlinear skew regional average, leading to misinterpretation.
#
# 2. it hide the underlying pattern and relationships within the regional data.

# %% [markdown]
# Task - 4 - Exploring Trends Across Metrics:
# Tasks:
# 1. Choose two metrics (e.g., Freedom to Make Life Choices and Generosity) and calculate their correlation
# {pearson correlation} with the Score for South Asian countries.

# %%
correlation_score_freedom = south_country_df['score'].corr(south_country_df['Freedom to make life choices'], method ='pearson')
correlation_score_generosity = south_country_df['score'].corr(south_country_df['Generosity'],method='pearson')
print(f'Correlation between Score and Freedom to Make Life Choices: {correlation_score_freedom}')
print(f'Correlation between Score and Generosity: {correlation_score_generosity}')
# Out:
# Correlation between Score and Freedom to Make Life Choices: 0.801497903141921
# Correlation between Score and Generosity: 0.8773326267276358

# %% [markdown]
# 2. Create scatter plots with trendlines for these metrics against the Score.

# %%
#score vs freedom
plt.figure(figsize=(10, 6))
sns.regplot(x='Freedom to make life choices', y='score', data=south_country_df)
plt.title('Scatter Plot of Score vs. Freedom to Make Life Choices')
plt.xlabel('Freedom to Make Life Choices')
plt.ylabel('Score')
plt.show()


#score vs generosity
plt.figure(figsize=(10, 6))
sns.regplot(x='Generosity', y='score', data=south_country_df)
plt.title('Scatter Plot of Score vs. Generosity')
plt.xlabel('Generosity')
plt.ylabel('Score')
plt.show()

# %% [markdown]
# 3. Identify and discuss the strongest and weakest relationships between these metrics and the Score for
# South Asian countries.
#
# -> The metrix  having higher absolute correaltion value which have the strongest relation with score indicating linear association between them whereas matrix having lower absolute value tends to have weakest relation with score.
# Although matrix having a strong corealtion with score doesn't necessary indicate that the changes in matrix directly cause change in score and might be influnced with other contextual factor while interpeting result.
#
#
# Example:
# The scatter plot I had created in Task 4 -2 provide visual insights .More defined treadline ,stronger the relation of matrix shoing more precise pattern between matrix and score meanwhile less defined treadline indicate weaker relation matrix.

# %% [markdown]
# Task - 5 - Gap Analysis:
# Tasks:
# 1. Add a new column, GDP-Score Gap, which is the difference between GDP per Capita and the Score
# for each South Asian country.

# %%
south_country_df['GDP-Score Gap'] = south_country_df['Log GDP per capita'] - south_country_df['score']
south_country_df
# Out:
#   Country name  score  Log GDP per capita  Social support  \
# 0        Nepal  5.158               0.965           0.990
# 1     Pakistan  4.657               1.069           0.600
# 2        India  4.054               1.166           0.653
# 3   Bangladesh  3.886               1.122           0.249
# 4  Afghanistan  1.721               0.628           0.000
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.443                         0.653       0.209
# 1                    0.321                         0.542       0.144
# 2                    0.417                         0.767       0.174
# 3                    0.513                         0.775       0.140
# 4                    0.242                         0.000       0.091
#
#    Perceptions of corruption  Dystopia + residual Happiness Cateogory  \
# 0                      0.115                1.783              Medium
# ...

# %% [markdown]
# 2. Rank the South Asian countries by this gap in both ascending and descending order.

# %%
#rank ascending
ascending_rank = south_country_df.sort_values(by='GDP-Score Gap', ascending=True)
ascending_rank[['Country name', 'GDP-Score Gap']]
# Out:
#   Country name  GDP-Score Gap
# 0        Nepal         -4.193
# 1     Pakistan         -3.588
# 2        India         -2.888
# 3   Bangladesh         -2.764
# 4  Afghanistan         -1.093

# %%
#rank descending
descending_rank = south_country_df.sort_values(by='GDP-Score Gap', ascending=False)
descending_rank[['Country name', 'GDP-Score Gap']]
# Out:
#   Country name  GDP-Score Gap
# 4  Afghanistan         -1.093
# 3   Bangladesh         -2.764
# 2        India         -2.888
# 1     Pakistan         -3.588
# 0        Nepal         -4.193

# %% [markdown]
# 3. Highlight the top 3 countries with the largest positive and negative gaps using a bar chart.

# %%
top_3_positive_gap = south_country_df.sort_values(by='GDP-Score Gap', ascending=False).head(3)
top_3_negative_gap = south_country_df.sort_values(by='GDP-Score Gap', ascending=True).head(3)

#for positive plot
top_countries = pd.concat([top_3_positive_gap, top_3_negative_gap])
plt.figure(figsize=(10, 6))
sns.barplot(x='Country name', y='GDP-Score Gap', data=top_3_positive_gap, hue='GDP-Score Gap')
plt.title('Top 3 Countries with Largest Positive Gaps')
plt.xlabel('Country')
plt.ylabel('GDP-Score Gap')

#for negative plot
top_countries = pd.concat([top_3_positive_gap, top_3_negative_gap])
plt.figure(figsize=(10, 6))
sns.barplot(x='Country name', y='GDP-Score Gap', data=top_3_negative_gap, hue='GDP-Score Gap')
plt.title('Top 3 Countries with Largest Negative Gaps')
plt.xlabel('Country')
plt.ylabel('GDP-Score Gap')
# Out:
# Text(0, 0.5, 'GDP-Score Gap')

# %% [markdown]
# 4. Analyze the reasons behind these gaps and their implications for South Asian countries.
#
# -> The gaps usally indicate the difference between country's GDP per capita and score(happiness) where we can conclude rich doesn;t gurantee happiness.
# Some factor contribute for this gaps are:
#
#
# 1.Non;economic factor: Score(happiness) is influnced by social support, healthy life expectancy, freedom to make life choices and corruption, if these factor is slightly delay resulting on the gap.
#
# 2.Unequal wealth: Although countries having higher gdp, the wealth oriincome isn't fairly shared among people.
#
# 3.Social and polotical Issues:Unstable government and social issue can make people upset.
#
# 4.Cultural issue: The essence to happiness might differ from each culture to culture and their views lead to difference in score(happiness) and economic factor.
#
#
# Implications for South Aian Countries:
# 1.Government focusing on non-economic factor like health,eduaction, social support insated of economic factor only.
#
# 2.Creating peacful and fair socities to make people ffel safe and enough opportunities for future .
#
# 3.Ensuring every people are being benefited from economical growth.

# %% [markdown]
# 3.3 Problem - 3 - Comparative Analysis:
# Task - 1 - Setup Task - Preparing the Middle Eastern Dataset:
# Tasks:
# 1. Similar in Task - 1 of Problem 2 create a dataframe from middle eastern countries. For hint use the
# following list:
# middle east countries = [ "Bahrain", "Iran", "Iraq", "Israel", "Jordan",
# "Kuwait", "Lebanon", "Oman", "Palestine", "Qatar", "Saudi Arabia", "Syria",
#
# "United Arab Emirates", "Yemen"]

# %%
middle_eastern_countries = ["Bahrain", "Iran", "Iraq", "Israel", "Jordan", "Kuwait", "Lebanon", "Oman", "Palestine", "Qatar", "Saudi Arabia", "Syria", "United Arab Emirates", "Yemen"]
middle_eastern_df = df[df['Country name'].isin(middle_eastern_countries)]
middle_eastern_df
# Out:
#              Country name  score  Log GDP per capita  Social support  \
# 4                  Israel  7.341               1.803           1.513
# 12                 Kuwait  6.951               1.845           1.364
# 21   United Arab Emirates  6.733               1.983           1.164
# 27           Saudi Arabia  6.594               1.842           1.361
# 61                Bahrain  5.959                 NaN             NaN
# 91                   Iraq  5.166               1.249           0.996
# 99                   Iran  4.923               1.435           1.136
# 124                Jordan  4.186               1.262           0.983
# 132                 Yemen  3.561               0.671           1.281
# 141               Lebanon  2.707               1.377           0.577
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 4                      0.740                         0.641       0.153
# ...

# %%
#probem 2
#new dataframe for Middle Eastern Countries
middle_eastern_df.to_csv('MiddleEasternCountries.csv', index=False)

# %% [markdown]
# Complete the following task:
# 1. Descriptive Statistics:
# • Calculate the mean, Standard deviation of the score for both South Asia and Middle East.
# • Which region has higher happiness Scores on average?

# %%
south_asian_mean_score = south_country_df['score'].mean()
south_asian_std_score = south_country_df['score'].std()
middle_eastern_mean_score = middle_eastern_df['score'].mean()
middle_eastern_std_score = middle_eastern_df['score'].std()
print("South Asia")
print(f'Mean Score for South Asia: {south_asian_mean_score}')
print(f'Standard Deviation of Score for South Asia: {south_asian_std_score}')
print('')
print("Middle Eastern")
print(f'Mean Score for Middle Eastern Countries: {middle_eastern_mean_score}')
print(f'Standard Deviation of Score for Middle Eastern Countries: {middle_eastern_std_score}')
print('')

#finding which have hiigh score(happiness)
if south_asian_mean_score > middle_eastern_mean_score:
    print("South Asia has higher happiness scores on average.")
elif south_asian_mean_score < middle_eastern_mean_score:
    print("Middle Eastern Countries have higher happiness scores on average.")
else:
    print("Both regions have the same average happiness scores.")
# Out:
# South Asia
# Mean Score for South Asia: 3.8952000000000004
# Standard Deviation of Score for South Asia: 1.3160025455902433
#
# Middle Eastern
# Mean Score for Middle Eastern Countries: 5.412100000000001
# Standard Deviation of Score for Middle Eastern Countries: 1.5662011684327144
#
# Middle Eastern Countries have higher happiness scores on average.

# %% [markdown]
# 2. Top and Bottom Performers:
# • Identify the top 3 and bottom 3 countries in each region based on the score.
# • Plot bar charts comparing these charts.

# %%
south_asia_top3=south_country_df.sort_values(by=['score'],ascending=False).head(3)
south_asia_bottom3=south_country_df.sort_values(by=['score']).head(3)


middle_east_top3=middle_eastern_df.sort_values(by=['score'],ascending=False).head(3)
middle_east_bottom3=middle_eastern_df.sort_values(by=['score']).head(3)
#Combine data for top 3 countries
top3_df = pd.concat([south_asia_top3, middle_east_top3])
top3_df['Region'] = ['South Asia'] * 3 + ['Middle East'] * 3

#Create the bar chart for top 3 countries
plt.figure(figsize=(10, 6))
sns.barplot(x='Country name', y='score', hue='Region', data=top3_df, palette='viridis')
plt.title('Top 3 Countries by Happiness Score')
plt.xlabel('Country')
plt.ylabel('Score')
plt.xticks(rotation=0, ha='center')
plt.tight_layout()
plt.show()


bottom3_df = pd.concat([south_asia_bottom3, middle_east_bottom3])
bottom3_df['Region'] = ['South Asia'] * 3 + ['Middle East'] * 3


plt.figure(figsize=(10, 6))
sns.barplot(x='Country name', y='score', hue='Region', data=bottom3_df, palette='viridis')
plt.title('Bottom 3 Countries by Happiness Score')
plt.xlabel('Country')
plt.ylabel('Happiness Score')
plt.xticks(rotation=0, ha='center')
plt.tight_layout()
plt.show()

# %% [markdown]
# 3. Metric Comparisons:
# • Compare key metrics like GDP per Capita, Social Support, and Healthy Life Expectancy
# between the regions using grouped bar charts.
# • Which metrics show the largest disparity between the two regions?

# %%
#2
#mean calulate
regional_averages = pd.DataFrame({
    'Region': ['South Asia', 'Middle East'],
    'Log GDP per capita': [south_country_df['Log GDP per capita'].mean(), middle_eastern_df['Log GDP per capita'].mean()],
    'Social support': [south_country_df['Social support'].mean(), middle_eastern_df['Social support'].mean()],
    'Healthy life expectancy': [south_country_df['Healthy life expectancy'].mean(), middle_eastern_df['Healthy life expectancy'].mean()]
})

#reshaping to plot
regional_averages_melted = regional_averages.melt(id_vars=['Region'], var_name='Metric', value_name='Average')

#barchart
plt.figure(figsize=(10, 6))
sns.barplot(x='Metric', y='Average', hue='Region', data=regional_averages_melted, palette='viridis')
plt.title("Comparison of Key Metrics between South Asia and the Middle East")
plt.xlabel("Metric")
plt.ylabel("Average Value")
plt.tight_layout()
plt.show()

# %% [markdown]
# 4. Happiness Disparity:
# • Compute the range (max - min) and coefficient of variation (CV) for Score in both regions.
# • Which region has greater variability in happiness?

# %%
south_asia_range = south_country_df['score'].max() - south_country_df['score'].min()
middle_east_range = middle_eastern_df['score'].max() - middle_eastern_df['score'].min()
#coefficient of variaion
south_asia_cv =  south_country_df['score'].std() / south_country_df['score'].mean()
middle_east_cv =  middle_eastern_df['score'].std() / middle_eastern_df['score'].mean()
print(f"Range for South Asia: {south_asia_range}")
print(f"Range for Middle East: {middle_east_range}")
print('')
print(f"Coefficient of Variation for South Asia: {south_asia_cv:.2f}%")
print(f"Coefficient of Variation for Middle East: {middle_east_cv:.2f}%")
print('')
#to determine whihc cv is greater
if south_asia_cv> middle_east_cv:
    print("South Asia has a greater range in happiness scores.")
elif south_asia_cv < middle_east_cv:
    print("Middle East has a greater range in happiness scores.")
else:
    print("Both regions have the same range in happiness scores.")
# Out:
# Range for South Asia: 3.4370000000000003
# Range for Middle East: 4.634
#
# Coefficient of Variation for South Asia: 0.34%
# Coefficient of Variation for Middle East: 0.29%
#
# South Asia has a greater range in happiness scores.

# %% [markdown]
# 5. Correlation Analysis:
# • Analyze the correlation of Score with other metrics Freedom to Make Life Choices, and
# Generosity within each region.
# • Create scatter plots to visualize and interpret the relationships.

# %%
# South Asia
south_asia_freedom_corr = south_country_df['score'].corr(south_country_df['Freedom to make life choices'])
south_asia_generosity_corr = south_country_df['score'].corr(south_country_df['Generosity'])

print(f"South Asia - Correlation with Freedom: {south_asia_freedom_corr}, Correlation with Generosity: {south_asia_generosity_corr}")

# Middle East
middle_east_freedom_corr = middle_eastern_df['score'].corr(middle_eastern_df['Freedom to make life choices'])
middle_east_generosity_corr = middle_eastern_df['score'].corr(middle_eastern_df['Generosity'])

print(f"Middle East - Correlation with Freedom: {middle_east_freedom_corr}, Correlation with Generosity: {middle_east_generosity_corr}")
# Out:
# South Asia - Correlation with Freedom: 0.801497903141921, Correlation with Generosity: 0.8773326267276358
# Middle East - Correlation with Freedom: 0.8632202433827544, Correlation with Generosity: 0.6275236536964182

# %% [markdown]
# #Create scatter plot to visualie and interpert relationships

# %%
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
sns.regplot(x='Freedom to make life choices', y='score', data=south_country_df, color='darkseagreen')
plt.title('South Asia: Freedom vs. Score')

plt.subplot(1, 2, 2)
sns.regplot(x='Generosity', y='score', data=south_country_df, color='royalblue')
plt.title('South Asia: Generosity vs. Score')

plt.tight_layout()
plt.show()

# Middle East
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
sns.regplot(x='Freedom to make life choices', y='score', data=middle_eastern_df, color='darkseagreen')
plt.title('Middle East: Freedom vs. Score')

plt.subplot(1, 2, 2)
sns.regplot(x='Generosity', y='score', data=middle_eastern_df, color='royalblue')
plt.title('Middle East: Generosity vs. Score')

plt.tight_layout()
plt.show()

# %% [markdown]
# #task 5
# Interpreting the Scatter Plots:
#
# South Asia:
#
# Freedom vs. Score: You'll likely see an upward trend in the points, indicating a positive correlation between freedom to make life choices and happiness. The regression line will also slope upwards.
# Generosity vs. Score: The points might be more scattered, with a less clear trend, reflecting the weaker correlation between generosity and happiness.
# Middle East:
#
# Freedom vs. Score: Similar to South Asia, you'll likely see an upward trend, but it might be less pronounced compared to South Asia, indicating a moderate positive correlation.
# Generosity vs. Score: The points will likely be even more scattered than in South Asia, suggesting a very weak or no clear relationship between generosity and happiness.
# Overall:
#
# The scatter plots provide a visual representation of the correlation analysis. They help confirm the strength and direction of the relationships between happiness and the other metrics in each region. By observing the trends in the points and the regression lines, you can gain a better understanding of how these variables are related.

# %% [markdown]
# 6. Outlier Detection:
# • Identify outlier countries in both regions based on Score and GDP per Capita.

# %%
def find_outliers_iqr(data, column):
    Q1 = data[column].quantile(0.25)
    Q3 = data[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers = data[(data[column] < lower_bound) | (data[column] > upper_bound)]
    return outliers

south_asia_score_outliers = find_outliers_iqr(south_country_df, 'score')
south_asia_gdp_outliers = find_outliers_iqr(south_country_df, 'Log GDP per capita')


middle_east_score_outliers = find_outliers_iqr(middle_eastern_df, 'score')
middle_east_gdp_outliers = find_outliers_iqr(middle_eastern_df, 'Log GDP per capita')

print("Discussion :")
print("\nSouth Asia Outliers:")
if len(south_asia_score_outliers) > 0:
    for index, row in south_asia_score_outliers.iterrows():
        print(f"Outlier Country: {row['Country name']}, Score: {row['score']}, GDP per Capita: {row['Log GDP per capita']}")
else:
    print("No outliers found based on Score in South Asia.")
print('')
print("Middle East Outliers:")
if len(middle_east_score_outliers) > 0:
    for index, row in middle_east_score_outliers.iterrows():
        print(f"Outlier Country: {row['Country name']}, Score: {row['score']}, GDP per Capita: {row['Log GDP per capita']}")
else:
    print("No outliers found based on Score in Middle East.")
# Out:
# Discussion :
#
# South Asia Outliers:
# Outlier Country: Afghanistan, Score: 1.721, GDP per Capita: 0.628
#
# Middle East Outliers:
# No outliers found based on Score in Middle East.

# %% [markdown]
# plot outlier

# %%
south_asia_all_outliers = pd.concat([south_asia_score_outliers, south_asia_gdp_outliers])

plt.figure(figsize=(8, 6))
sns.scatterplot(x='Log GDP per capita', y='score', data=south_country_df, color='blue', label='South Asia Countries')
sns.scatterplot(x='Log GDP per capita', y='score', data=south_asia_all_outliers, color='red', label='Outliers')
plt.title("Outlier Countries in South Asia")
plt.xlabel('Log GDP per capita')
plt.ylabel('Happiness Score')
plt.legend()
plt.tight_layout()
plt.show()


middle_east_all_outliers = pd.concat([middle_east_score_outliers, middle_east_gdp_outliers])
#middle no outlier
plt.figure(figsize=(8, 6))
sns.scatterplot(x='Log GDP per capita', y='score', data=middle_eastern_df, color='blue', label='Middle East Countries')
sns.scatterplot(x='Log GDP per capita', y='score', data=middle_east_all_outliers, color='red', label='Outliers')
plt.title("Outlier Countries in Middle East")
plt.xlabel('Log GDP per capita')
plt.ylabel('Happiness Score')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# Discuss of Implications:
#
# The country having outliers likely tend to  have unique social,economic and political factors directly influencing happiness level compare to other countries having no outliersand most impoertant outlier help to make policies for beter focus specific country's for their low score(happiness) level.

# %% [markdown]
# 7. Visualization:
# • Create boxplots comparing the distribution of Score between South Asia and the Middle East.
# • Interpret the key differences in distribution shapes, medians, and outliers.

# %%
#Comaprasion of score distribution
combined_df = pd.concat([south_country_df.assign(Region='South Asia'),
                         middle_eastern_df.assign(Region='Middle East')])
plt.figure(figsize=(10, 6))
sns.boxplot(x='Region', y='score', data=combined_df)
plt.title("Distribution of Score between South Asia and Middle East")
plt.xlabel("Region")
plt.ylabel("Score")
plt.show()

# %%
# Interpret the key differences in distribution shapes, medians, and outliers.
print("Interpretation:")
print("\nKey Differences:")
print("Distribution Shape:")
print("South Asia: Generally, the distribution appears to be wider with more variance.")
print("Middle East: Tends to have a narrower distribution with less variance.")
print("\nMedian Values:")
print("South Asia: The median Score is relatively lower, indicating a more widespread variation among countries.")
print("Middle East: The median Score is higher, suggesting that scores are more concentrated around the average value.")
print("\nOutliers:")
print("South Asia: There are more outliers, indicating significant deviations from the typical happiness score.")
print("Middle East: Fewer outliers suggest a more uniform distribution among the countries.")
# Out:
# Interpretation:
#
# Key Differences:
# Distribution Shape:
# South Asia: Generally, the distribution appears to be wider with more variance.
# Middle East: Tends to have a narrower distribution with less variance.
#
# Median Values:
# South Asia: The median Score is relatively lower, indicating a more widespread variation among countries.
# Middle East: The median Score is higher, suggesting that scores are more concentrated around the average value.
#
# Outliers:
# South Asia: There are more outliers, indicating significant deviations from the typical happiness score.
# Middle East: Fewer outliers suggest a more uniform distribution among the countries.
